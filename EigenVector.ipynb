# %% [markdown]
# EigenValue, Eigenvector 계산하기

# %%
from IPython.display import Image

# %%
Image("eigen.jpeg")

# %% [markdown]
# 파이썬에서 EigenValue, Eigenvector 찾기

# %%
import numpy as np
import scipy.linalg as la

# %%
A = np.array([[2,6],[5,3]])
print(A)
# Out:
# [[2 6]
#  [5 3]]

# %%
results = la.eig(A)

# %%
print(results[0])
# Out:
# [-3.+0.j  8.+0.j]

# %%
print(results[1])
# Out:
# [[-0.76822128 -0.70710678]
#  [ 0.6401844  -0.70710678]]
